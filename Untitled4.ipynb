# %%
import pandas as pd

# %%
df = pd.read_csv('exportt.csv')

# %%
df
# Out:
#     tag  tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# 0     1  18.1  13.8  23.6   0.3   NaN   225  13.1   NaN  1015.8   NaN
# 1     2  20.2  14.0  27.8   0.0   NaN   187   6.4   NaN  1020.1   NaN
# 2     3  19.4  14.4  26.1   0.0   NaN    41   6.5   NaN  1025.6   NaN
# 3     4  20.7  12.0  27.7   0.0   NaN    90  14.6   NaN  1025.4   NaN
# 4     5  21.0  14.4  28.1   0.0   NaN    99  16.6   NaN  1021.4   NaN
# 5     6  19.9  10.5  29.3   0.0   NaN    87  11.3   NaN  1020.5   NaN
# 6     7  20.4  12.5  29.7   0.0   NaN    90  11.9   NaN  1019.7   NaN
# 7     8  21.0  12.4  29.6   0.0   NaN    83   8.4   NaN  1018.5   NaN
# 8     9  21.6  14.2  30.3   0.0   NaN    96   6.6   NaN  1017.7   NaN
# 9    10  21.8  14.4  30.6   0.0   NaN    26   5.6   NaN  1018.0   NaN
# 10   11  21.5  13.5  30.4   0.0   NaN   107   6.0   NaN  1015.1   NaN
# 11   12  22.8  14.2  31.0   0.1   NaN   183   7.3   NaN  1012.6   NaN
# 12   13  19.9  17.8  23.2   0.0   NaN   274  10.9   NaN  1016.4   NaN
# 13   14  17.1  11.4  23.3   0.0   NaN    26   7.5   NaN  1021.3   NaN
# 14   15  17.9   9.4  26.7   0.0   NaN    84  10.6   NaN  1017.9   NaN
# 15   16  21.1  12.6  29.2   0.0   NaN    96   8.7   NaN  1014.9   NaN
# 16   17  23.5  15.7  29.8   0.9   NaN   157   8.5   NaN  1014.6   NaN
# 17   18  19.7  16.3  23.6   4.3   NaN   183  11.8   NaN  1010.7   NaN
# 18   19  18.4  15.1  22.2   0.0   NaN   243  16.9   NaN  1014.8   NaN
# 19   20  19.3  14.9  26.2   0.2   NaN   173  10.1   NaN  1012.7   NaN
# 20   21  19.2  13.7  26.8  10.6   NaN   177   9.5   NaN  1003.4   NaN
# 21   22  15.2  12.0  19.7   2.9   NaN   209  14.2   NaN  1005.5   NaN
# 22   23  13.6   8.6  18.5   0.0   NaN   248  12.3   NaN  1016.9   NaN
# 23   24  12.6   5.9  20.6   0.0   NaN   126   7.9   NaN  1026.0   NaN
# 24   25  14.2   6.5  22.5   0.0   NaN   100  10.7   NaN  1024.2   NaN
# 25   26  15.3   7.2  24.5   0.0   NaN   104   6.2   NaN  1021.9   NaN
# 26   27  16.2   7.9  25.7   0.0   NaN   127   7.4   NaN  1020.2   NaN
# 27   28  18.1  11.4  27.6   0.0   NaN   180   7.4   NaN  1018.6   NaN
# 28   29  18.9  11.2  27.7   0.0   NaN   210  14.4   NaN  1019.9   NaN
# 29   30  15.9  10.1  21.3   0.0   NaN   312   9.0   NaN  1026.5   NaN

# %%
df.columns
# Out:
# Index(['tag', 'tavg', 'tmin', 'tmax', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt',
#        'pres', 'tsun'],
#       dtype='object')

# %%
df_filtered = df[["tag","tavg","tmin","tmax"]]

# %%
df_filtered= df_filtered.dropna()

# %%
df_filtered
# Out:
#     tag  tavg  tmin  tmax
# 0     1  18.1  13.8  23.6
# 1     2  20.2  14.0  27.8
# 2     3  19.4  14.4  26.1
# 3     4  20.7  12.0  27.7
# 4     5  21.0  14.4  28.1
# 5     6  19.9  10.5  29.3
# 6     7  20.4  12.5  29.7
# 7     8  21.0  12.4  29.6
# 8     9  21.6  14.2  30.3
# 9    10  21.8  14.4  30.6
# 10   11  21.5  13.5  30.4
# 11   12  22.8  14.2  31.0
# 12   13  19.9  17.8  23.2
# 13   14  17.1  11.4  23.3
# 14   15  17.9   9.4  26.7
# 15   16  21.1  12.6  29.2
# 16   17  23.5  15.7  29.8
# 17   18  19.7  16.3  23.6
# 18   19  18.4  15.1  22.2
# 19   20  19.3  14.9  26.2
# 20   21  19.2  13.7  26.8
# 21   22  15.2  12.0  19.7
# 22   23  13.6   8.6  18.5
# 23   24  12.6   5.9  20.6
# 24   25  14.2   6.5  22.5
# 25   26  15.3   7.2  24.5
# 26   27  16.2   7.9  25.7
# 27   28  18.1  11.4  27.6
# 28   29  18.9  11.2  27.7
# 29   30  15.9  10.1  21.3

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

X=df_filtered[["tag"]].values
y=df_filtered[["tavg","tmin","tmax"]].values

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0,test_size=0.25)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train,y_train)

y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([[21.31290742, 14.17911141, 28.99761433],
#        [15.84417524, 10.5973045 , 21.82707275],
#        [18.99921304, 12.66373157, 25.96392366],
#        [19.6302206 , 13.07701698, 26.79129384],
#        [16.26484695, 10.87282811, 22.37865287],
#        [16.68551865, 11.14835172, 22.93023299],
#        [16.05451109, 10.7350663 , 22.10286281],
#        [19.41988474, 12.93925517, 26.51550378]])

# %%
print(model.intercept_)
# Out:
# [21.94391498 14.59239683 29.82498451]

# %%
print(model.coef_)
# Out:
# [[-0.21033585]
#  [-0.1377618 ]
#  [-0.27579006]]

# %%
print(model.predict([[31]]))
# Out:
# [[15.42350353 10.32178089 21.27549263]]
